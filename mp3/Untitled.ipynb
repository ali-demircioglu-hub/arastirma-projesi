# %%
import pandas as pd

# CSV dosyasını okuma
file_path = 'C:/Users/EXCALİBUR/Desktop/okul dosyaları/Araştırma Yöntem ve Teknikleri/data_mp3.csv.csv' 

try:
    df = pd.read_csv(file_path)
    df.index = range(1, len(df) + 1)
    print(f"'{file_path}' dosyası başarıyla DataFrame'e yüklendi.")
    
    # DataFrame'in ilk 6 satırını gösterme (df.head())
    print("\n--- İlk 6 Satır (df.head(6)) ---")
    print(df.head(6))
    
    # ... (Diğer kod satırları) ...

except FileNotFoundError:
    print(f"HATA: '{file_path}' dosyası bulunamadı. Lütfen dosya yolunu kontrol edin.")
except Exception as e:
    print(f"Veri okunurken bir hata oluştu: {e}")
# Out:
# 'C:/Users/EXCALİBUR/Desktop/okul dosyaları/Araştırma Yöntem ve Teknikleri/data_mp3.csv.csv' dosyası başarıyla DataFrame'e yüklendi.
#
# --- İlk 6 Satır (df.head(6)) ---
#          Zaman damgası ne sıklıkla müzik dinlersiniz?  \
# 1  17.11.2025 18:34:26                        çok sık
# 2  17.11.2025 18:36:46              ortalama sıklıkta
# 3  17.11.2025 18:38:33                     genellikle
# 4  17.11.2025 18:38:47                        çok sık
# 5  17.11.2025 18:42:09                  neredeyse hiç
# 6  17.11.2025 18:43:00              ortalama sıklıkta
#
#   hangi müzik dinleme uygulamasını kullanıyorsunuz?  \
# 1                                           spotify
# 2                                           spotify
# 3                                     youtube music
# 4                                           spotify
# 5                                             diğer
# 6                                           spotify
#
# ...
